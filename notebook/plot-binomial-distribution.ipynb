# %%
using Plots

# %%
# Binomial(n, θ) distribution
p(x; n, θ) = binomial(n, x) * θ^x * (1 - θ)^(n - x)

pl = plot(size=(600,300))
n = 20
x = 0:n
for θ in [0.1 0.3 0.5]
    scatter!(pl, x, p.(x; n, θ), label="$n, $θ")
end

pl
